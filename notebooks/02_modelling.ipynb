# %% [markdown]
# # Heart Disease Risk Prediction - Modelling And Final Evaluation
#
# This notebook orchestrates the tested modelling pipeline. It compares classifiers, tunes the strongest candidates, evaluates the locked model once on the held-out test set, and regenerates final reports.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src import SEED

SEED

# %% [markdown]
# ## Preprocessing And Baseline Model Comparison
#
# Every classifier uses the same `ColumnTransformer` inside a scikit-learn `Pipeline`, so imputation, scaling, and encoding are fitted inside training folds only.

# %%
from src.model_preprocess import run_preprocessing_inspection
from src.models import run_baseline_model_comparison

preprocessing = run_preprocessing_inspection()
baseline = run_baseline_model_comparison()

baseline.summary.head()

# %% [markdown]
# ## Evaluation, Tuning, And Interpretation
#
# Model selection uses cross-validation and out-of-fold predictions on the training split. The held-out test set is evaluated only after the final model and threshold are locked.

# %%
from src.evaluate import run_model_evaluation
from src.tune import run_hyperparameter_tuning
from src.interpret import run_feature_interpretation

evaluation = run_model_evaluation()
tuning = run_hyperparameter_tuning()
interpretation = run_feature_interpretation()

tuning.selected_model

# %% [markdown]
# ## Visualization QA, Final Model Package, And Reports
#
# The final stage verifies required plots, evaluates the test set once, serializes the fitted pipeline locally, and regenerates the milestone/final reports.

# %%
from src.plots import run_visualization_qa
from src.finalize import run_finalization
from src.reporting import run_reporting

visualization = run_visualization_qa()
finalization = run_finalization()
reports = run_reporting()

finalization.final_metrics

# %% [markdown]
# ## Generated Final Artifacts
#
# - `reports/BASELINE_MODEL_COMPARISON.md`
# - `reports/MODEL_EVALUATION_REPORT.md`
# - `reports/HYPERPARAMETER_TUNING_REPORT.md`
# - `reports/FEATURE_IMPORTANCE_REPORT.md`
# - `reports/VISUALIZATION_REPORT.md`
# - `reports/FINAL_TEST_EVALUATION_REPORT.md`
# - `reports/MODEL_CARD.md`
# - `reports/FINAL_PROJECT_REPORT.md`
