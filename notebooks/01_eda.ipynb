# %% [markdown]
# # Heart Disease Risk Prediction - Data Understanding And EDA
#
# This notebook is intentionally thin: reusable, tested logic lives in `src/`, while the notebook orchestrates the data-understanding, cleaning, EDA, and outlier-review stages for grading and presentation.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src import SEED

SEED

# %% [markdown]
# ## Dataset Audit, Schema, And Cleaning
#
# The raw dataset is loaded from `data/raw/heart.csv`. The cleaning stage removes one duplicate row and decodes sentinel values in `ca` and `thal` to missing values for leak-proof pipeline imputation later.

# %%
from src.data import run_initial_audit
from src.schema import run_schema_validation
from src.preprocess import run_data_cleaning

audit = run_initial_audit()
run_schema_validation()
cleaning = run_data_cleaning()

audit.shape, cleaning.cleaned.shape

# %% [markdown]
# ## Exploratory Analysis And Outlier Review
#
# EDA and outlier detection are performed on the training split only. Generated reports and figures are saved under `reports/` and `outputs/figures/`.

# %%
from src.eda import run_eda
from src.outliers import run_outlier_detection

eda = run_eda()
outliers = run_outlier_detection()

eda.target_distribution, outliers.iqr_summary

# %% [markdown]
# ## Generated Milestone Artifacts
#
# - `reports/INITIAL_DATA_AUDIT.md`
# - `reports/DATA_DICTIONARY.md`
# - `reports/DATA_CLEANING_REPORT.md`
# - `reports/EXPLORATORY_DATA_ANALYSIS.md`
# - `reports/OUTLIER_DETECTION_REPORT.md`
